# %% [markdown]
# <a href="https://colab.research.google.com/github/timBrockman/lcai/blob/master/Chapter_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url="https://data.cdc.gov/api/views/55yu-xksw/rows.csv?accessType=DOWNLOAD"
heart_df = pd.read_csv(url, index_col=0)

# %%
heart_df.head()
# Out:
#      LocationAbbr           LocationDesc GeographicLevel DataSource  \
# Year
# 2020           AK        Kenai Peninsula          County       NVSS
# 2020           AL          Walker County          County       NVSS
# 2020           AL       St. Clair County          County       NVSS
# 2020           AR            Yell County          County       NVSS
# 2020           AS  American Samoa County          County       NVSS
#
#                         Class                    Topic  Data_Value  \
# Year
# 2020  Cardiovascular Diseases  Heart Disease Mortality       165.1
# 2020  Cardiovascular Diseases  Heart Disease Mortality       109.0
# 2020  Cardiovascular Diseases  Heart Disease Mortality        90.0
# 2020  Cardiovascular Diseases  Heart Disease Mortality         NaN
# 2020  Cardiovascular Diseases  Heart Disease Mortality         NaN
#
#              Data_Value_Unit  \
# Year
# 2020  per 100,000 population
# 2020  per 100,000 population
# 2020  per 100,000 population
# ...

# %%
heart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 78792 entries, 2020 to 2020
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   LocationAbbr                78792 non-null  object
#  1   LocationDesc                78792 non-null  object
#  2   GeographicLevel             78792 non-null  object
#  3   DataSource                  78792 non-null  object
#  4   Class                       78792 non-null  object
#  5   Topic                       78792 non-null  object
#  6   Data_Value                  34430 non-null  float64
#  7   Data_Value_Unit             78792 non-null  object
#  8   Data_Value_Type             78792 non-null  object
#  9   Data_Value_Footnote_Symbol  44362 non-null  object
#  10  Data_Value_Footnote         44362 non-null  object
#  11  StratificationCategory1     78792 non-null  object
#  12  Stratification1             78792 non-null  object
# ...

# %%
heart_df = pd.read_csv('/content/drive/MyDrive/Heart_Disease_Mortality_Data_Among_US_Adults__35___by_State_Territory_and_County___2019-2021.csv', on_bad_lines='skip', engine="python")
heart_df.head()
# Out:
#    Year LocationAbbr           LocationDesc GeographicLevel DataSource  \
# 0  2020           AK        Kenai Peninsula          County       NVSS
# 1  2020           AL          Walker County          County       NVSS
# 2  2020           AL       St. Clair County          County       NVSS
# 3  2020           AR            Yell County          County       NVSS
# 4  2020           AS  American Samoa County          County       NVSS
#
#                      Class                    Topic Data_Value  \
# 0  Cardiovascular Diseases  Heart Disease Mortality      165.1
# 1  Cardiovascular Diseases  Heart Disease Mortality        109
# 2  Cardiovascular Diseases  Heart Disease Mortality         90
# 3  Cardiovascular Diseases  Heart Disease Mortality        NaN
# 4  Cardiovascular Diseases  Heart Disease Mortality        NaN
#
#           Data_Value_Unit                                    Data_Value_Type  \
# 0  per 100,000 population  Age-adjusted, Spatially Smoothed, 3-year Avera...
# ...

# %%
heart_df.isnull().sum()
# Out:
# Year                              0
# LocationAbbr                      1
# LocationDesc                      1
# GeographicLevel                   1
# DataSource                        1
# Class                             1
# Topic                             1
# Data_Value                    66803
# Data_Value_Unit                   1
# Data_Value_Type                   1
# Data_Value_Footnote_Symbol    51178
# Data_Value_Footnote           51178
# StratificationCategory1           2
# Stratification1                   2
# StratificationCategory2           3
# Stratification2                   4
# TopicID                           5
# LocationID                        5
# Y_lat                            54
# X_lon                            54
# Georeference                     54
# dtype: int64

# %%
heart_df.Stratification2.unique()
# Out:
# array(['Hispanic', 'Asian', 'Black', 'More than one race',
#        'American Indian or Alaska Native', 'White', 'Overall',
#        'Native Hawaiian or Other Pacific Islander', None,
#        'POINT (-114.1200236 46.074151841)', '33.609846507'], dtype=object)

# %%
import seaborn as sns

# %%
sns.violinplot(x="Data_Value", y="Stratification2", data=heart_df)
# Out:
# <Axes: xlabel='Data_Value', ylabel='Stratification2'>

# %%
sns.distplot(heart_df['Data_Value'])
# Out:
# <ipython-input-13-d15275363afd>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(heart_df['Data_Value'])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-d15275363afd> in <cell line: 1>()
# ----> 1 sns.distplot(heart_df['Data_Value'])
#
# /usr/local/lib/python3.10/dist-packages/seaborn/distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax, x)
#    2441
#    2442     # Make a a 1-d float array
# ...
